# %%
import pandas as pd

game_df = pd.read_csv(r'..\data\games.csv')
game_df.head(3)
# Out:
#    BGGId          Name                                        Description  \
# 0      1    Die Macher  die macher game seven sequential political rac...
# 1      2  Dragonmaster  dragonmaster tricktaking card game base old ga...
# 2      3       Samurai  samurai set medieval japan player compete gain...
#
#    YearPublished  GameWeight  AvgRating  BayesAvgRating   StdDev  MinPlayers  \
# 0           1986      4.3206    7.61428         7.10363  1.57979           3
# 1           1981      1.9630    6.64537         5.78447  1.45440           3
# 2           1998      2.4859    7.45601         7.23994  1.18227           2
#
#    MaxPlayers  ...  Rank:partygames  Rank:childrensgames  Cat:Thematic  \
# 0           5  ...            21926                21926             0
# 1           4  ...            21926                21926             0
# 2           4  ...            21926                21926             0
#
# ...

# %%
print('데이터 프레임 크기: ', game_df.shape)
# Out:
# 데이터 프레임 크기:  (21925, 48)

# %%
game_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21925 entries, 0 to 21924
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   BGGId                21925 non-null  int64
#  1   Name                 21925 non-null  str
#  2   Description          21924 non-null  str
#  3   YearPublished        21925 non-null  int64
#  4   GameWeight           21925 non-null  float64
#  5   AvgRating            21925 non-null  float64
#  6   BayesAvgRating       21925 non-null  float64
#  7   StdDev               21925 non-null  float64
#  8   MinPlayers           21925 non-null  int64
#  9   MaxPlayers           21925 non-null  int64
#  10  ComAgeRec            16395 non-null  float64
#  11  LanguageEase         16034 non-null  float64
#  12  BestPlayers          21925 non-null  int64
#  13  GoodPlayers          21925 non-null  str
#  14  NumOwned             21925 non-null  int64
# ...

# %%
game_df.describe()
# Out:
#                BGGId  YearPublished    GameWeight     AvgRating  \
# count   21925.000000   21925.000000  21925.000000  21925.000000
# mean   117652.663216    1985.494914      1.982131      6.424922
# std    104628.721777     212.486214      0.848983      0.932477
# min         1.000000   -3500.000000      0.000000      1.041330
# 25%     12346.000000    2001.000000      1.333300      5.836960
# 50%    105305.000000    2011.000000      1.968800      6.453950
# 75%    206169.000000    2017.000000      2.525200      7.052450
# max    349161.000000    2021.000000      5.000000      9.914290
#
#        BayesAvgRating        StdDev    MinPlayers    MaxPlayers     ComAgeRec  \
# count    21925.000000  21925.000000  21925.000000  21925.000000  16395.000000
# mean         5.685673      1.516374      2.007343      5.707868     10.004391
# std          0.365311      0.285578      0.693093     15.014643      3.269157
# ...

# %%
value_counts = game_df['GoodPlayers'].value_counts()
print(value_counts)
# Out:
# GoodPlayers
# []                                          19946
# ['2', '3', '4']                               600
# ['3', '4', '5']                               185
# ['2']                                         158
# ['1', '2', '3', '4']                          140
#                                             ...
# ['2', '6']                                      1
# ['5', '6', '7', '8', '9', '10', '11']           1
# ['6', '7', '8', '9', '10']                      1
# ['1', '2', '3', '4', '4+']                      1
# ['1', '2', '3', '4', '5', '6', '7', '8']        1
# Name: count, Length: 78, dtype: int64

# %%
game_YearPublished = game_df['YearPublished']
print(type(game_YearPublished))
# Out:
# <class 'pandas.Series'>

# %%
game_YearPublished.head()
# Out:
# 0    1986
# 1    1981
# 2    1998
# 3    1992
# 4    1964
# Name: YearPublished, dtype: int64

# %%
value_counts = game_df['GoodPlayers'].value_counts()
print(type(value_counts))
print(value_counts)
# Out:
# <class 'pandas.Series'>
# GoodPlayers
# []                                          19946
# ['2', '3', '4']                               600
# ['3', '4', '5']                               185
# ['2']                                         158
# ['1', '2', '3', '4']                          140
#                                             ...
# ['2', '6']                                      1
# ['5', '6', '7', '8', '9', '10', '11']           1
# ['6', '7', '8', '9', '10']                      1
# ['1', '2', '3', '4', '4+']                      1
# ['1', '2', '3', '4', '5', '6', '7', '8']        1
# Name: count, Length: 78, dtype: int64
